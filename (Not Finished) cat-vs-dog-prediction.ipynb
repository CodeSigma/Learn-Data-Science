# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    print(dirname)
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input
# /kaggle/input/cat-and-dog
# /kaggle/input/cat-and-dog/test_set
# /kaggle/input/cat-and-dog/test_set/test_set
# /kaggle/input/cat-and-dog/test_set/test_set/dogs
# /kaggle/input/cat-and-dog/test_set/test_set/cats
# /kaggle/input/cat-and-dog/training_set
# /kaggle/input/cat-and-dog/training_set/training_set
# /kaggle/input/cat-and-dog/training_set/training_set/dogs
# /kaggle/input/cat-and-dog/training_set/training_set/cats

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense, BatchNormalization
from keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.models import load_model
from keras.preprocessing import image
from sklearn.metrics import accuracy_score
from keras.optimizers import Adam
import keras.backend as K
import tensorflow as tf
import numpy as np
import os
import time

# %%
train_dir = "../input/cat-and-dog/training_set/training_set"
test_dir = "../input/cat-and-dog/test_set/test_set"

# %%
os.listdir("../input/cat-and-dog/training_set/training_set")
# Out:
# ['dogs', 'cats']

# %%
import cv2
import matplotlib.pyplot as plt

#get image size from dataset
img = load_img('/kaggle/input/cat-and-dog/training_set/training_set/cats/cat.2750.jpg')  # this is a PIL image
x = img_to_array(img)
print(x.shape)
plt.figure(figsize=(5,5))
x = cv2.resize(x, (192, 256))
print(x.shape)
plt.imshow(x/255)
# Out:
# (375, 499, 3)
# (256, 192, 3)

# %%
batch_size = 64
lr = 3e-3

# %%
train_datagen = ImageDataGenerator(
    rescale = 1./255,
    rotation_range=0.3,
    shear_range=0.2,
    zoom_range=0.5,
    validation_split=0.2
)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(x.shape[0], x.shape[1]),
    batch_size= batch_size,
    class_mode='binary',
    subset='training'
)

valid_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size = (x.shape[0], x.shape[1]),
    batch_size = batch_size,
    class_mode = "binary",
    subset = "validation"
)


# valid_datagen = ImageDataGenerator(
#     rescale=1./255)
# Out:
# Found 6404 images belonging to 2 classes.
# Found 1601 images belonging to 2 classes.

# %%
# test_datagen = ImageDataGenerator(rescale = 1./255)
# test_set = test_datagen.flow_from_directory(test_dir,
#                                             target_size=(x.shape[0], x.shape[1]),
#                                             batch_size = batch_size,
#                                             class_mode = 'binary')

# %%
def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

gamma = 2.0
epsilon = K.epsilon()
def focal_loss(y_true, y_pred):
    pt = y_pred * y_true + (1-y_pred) * (1-y_true)
    pt = K.clip(pt, epsilon, 1-epsilon)
    CE = -K.log(pt)
    FL = K.pow(1-pt, gamma) * CE
    loss = K.sum(FL, axis=1)
    return loss

# %%
model = Sequential()
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(x.shape[0], x.shape[1], 3)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, (3, 3)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())  # this converts our 3D feature maps to 1D feature vectors
model.add(Dense(512))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dense(512))
model.add(BatchNormalization())
model.add(Activation('relu'))
# model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 254, 190, 32)      896
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 254, 190, 32)      128
# _________________________________________________________________
# activation_6 (Activation)    (None, 254, 190, 32)      0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 127, 95, 32)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 125, 93, 64)       18496
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 125, 93, 64)       256
# _________________________________________________________________
# activation_7 (Activation)    (None, 125, 93, 64)       0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 62, 46, 64)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 60, 44, 128)       73856
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 60, 44, 128)       512
# _________________________________________________________________
# activation_8 (Activation)    (None, 60, 44, 128)       0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 30, 22, 128)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 84480)             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               43254272
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 512)               2048
# _________________________________________________________________
# activation_9 (Activation)    (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               262656
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 512)               2048
# _________________________________________________________________
# activation_10 (Activation)   (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 513
# _________________________________________________________________
# activation_11 (Activation)   (None, 1)                 0
# =================================================================
# Total params: 43,615,681
# Trainable params: 43,613,185
# Non-trainable params: 2,496
# _________________________________________________________________

# %%
model.compile(optimizer=Adam(lr),
              loss="binary_crossentropy",   
              metrics=["accuracy",f1_m,precision_m, recall_m])

# %%
epochs = 80

early_stop = EarlyStopping(patience=10, verbose=1, monitor='val_f1_m', mode='max')
reduce_lr =  ReduceLROnPlateau(monitor='val_f1_m', factor=0.1, patience=7, min_delta=1e-4, mode='max')
checkpoint = ModelCheckpoint(os.path.join("models.h5"), save_weights_only=True,
                             verbose=1, save_best_only=True, monitor='val_f1_m', mode='max')

# %%
#training the model
history = model.fit(
        train_generator,
        steps_per_epoch = int(train_generator.samples) // batch_size,
        validation_data = valid_generator,
        epochs = epochs,
        callbacks=[early_stop, checkpoint])
# Out:
# Epoch 1/80
# 100/100 [==============================] - 108s 1s/step - loss: 0.5970 - accuracy: 0.6765 - f1_m: 0.6674 - precision_m: 0.6917 - recall_m: 0.6548 - val_loss: 0.6770 - val_accuracy: 0.5834 - val_f1_m: 0.5533 - val_precision_m: 0.5619 - val_recall_m: 0.5504
#
# Epoch 00001: val_f1_m improved from -inf to 0.55329, saving model to models.h5
# Epoch 2/80
# 100/100 [==============================] - 109s 1s/step - loss: 0.5910 - accuracy: 0.6809 - f1_m: 0.6717 - precision_m: 0.6902 - recall_m: 0.6674 - val_loss: 0.6746 - val_accuracy: 0.5903 - val_f1_m: 0.6293 - val_precision_m: 0.5428 - val_recall_m: 0.7544
#
# Epoch 00002: val_f1_m improved from 0.55329 to 0.62926, saving model to models.h5
# Epoch 3/80
# 100/100 [==============================] - 107s 1s/step - loss: 0.5880 - accuracy: 0.6855 - f1_m: 0.6605 - precision_m: 0.7080 - recall_m: 0.6391 - val_loss: 0.6524 - val_accuracy: 0.6271 - val_f1_m: 0.5203 - val_precision_m: 0.6765 - val_recall_m: 0.4301
#
# Epoch 00003: val_f1_m did not improve from 0.62926
# Epoch 4/80
# 100/100 [==============================] - 107s 1s/step - loss: 0.5650 - accuracy: 0.7068 - f1_m: 0.6977 - precision_m: 0.7196 - recall_m: 0.6939 - val_loss: 0.8758 - val_accuracy: 0.5253 - val_f1_m: 0.6858 - val_precision_m: 0.5322 - val_recall_m: 0.9900
#
# Epoch 00004: val_f1_m improved from 0.62926 to 0.68580, saving model to models.h5
# Epoch 5/80
# 100/100 [==============================] - 108s 1s/step - loss: 0.5400 - accuracy: 0.7246 - f1_m: 0.7112 - precision_m: 0.7408 - recall_m: 0.6927 - val_loss: 0.6449 - val_accuracy: 0.6477 - val_f1_m: 0.5644 - val_precision_m: 0.6710 - val_recall_m: 0.4905
#
# Epoch 00005: val_f1_m did not improve from 0.68580
# Epoch 6/80
# 100/100 [==============================] - 109s 1s/step - loss: 0.5184 - accuracy: 0.7416 - f1_m: 0.7321 - precision_m: 0.7550 - recall_m: 0.7166 - val_loss: 0.9296 - val_accuracy: 0.5815 - val_f1_m: 0.6471 - val_precision_m: 0.5305 - val_recall_m: 0.8367
#
# Epoch 00006: val_f1_m did not improve from 0.68580
# Epoch 7/80
# 100/100 [==============================] - 108s 1s/step - loss: 0.5022 - accuracy: 0.7569 - f1_m: 0.7430 - precision_m: 0.7623 - recall_m: 0.7328 - val_loss: 0.5872 - val_accuracy: 0.7108 - val_f1_m: 0.6524 - val_precision_m: 0.7359 - val_recall_m: 0.5916
#
# Epoch 00007: val_f1_m did not improve from 0.68580
# Epoch 8/80
# 100/100 [==============================] - 109s 1s/step - loss: 0.4823 - accuracy: 0.7645 - f1_m: 0.7613 - precision_m: 0.7733 - recall_m: 0.7560 - val_loss: 0.5483 - val_accuracy: 0.7077 - val_f1_m: 0.6562 - val_precision_m: 0.7188 - val_recall_m: 0.6118
#
# Epoch 00008: val_f1_m did not improve from 0.68580
# Epoch 9/80
# 100/100 [==============================] - 107s 1s/step - loss: 0.4591 - accuracy: 0.7830 - f1_m: 0.7772 - precision_m: 0.7931 - recall_m: 0.7697 - val_loss: 0.6209 - val_accuracy: 0.6833 - val_f1_m: 0.6557 - val_precision_m: 0.6626 - val_recall_m: 0.6590
#
# Epoch 00009: val_f1_m did not improve from 0.68580
# Epoch 10/80
# 100/100 [==============================] - 108s 1s/step - loss: 0.4546 - accuracy: 0.7825 - f1_m: 0.7799 - precision_m: 0.7975 - recall_m: 0.7726 - val_loss: 0.6204 - val_accuracy: 0.7083 - val_f1_m: 0.7520 - val_precision_m: 0.6758 - val_recall_m: 0.8522
#
# Epoch 00010: val_f1_m improved from 0.68580 to 0.75200, saving model to models.h5
# Epoch 11/80
# 100/100 [==============================] - 107s 1s/step - loss: 0.4284 - accuracy: 0.8046 - f1_m: 0.7984 - precision_m: 0.8173 - recall_m: 0.7882 - val_loss: 0.5821 - val_accuracy: 0.7183 - val_f1_m: 0.6938 - val_precision_m: 0.6841 - val_recall_m: 0.7077
#
# Epoch 00011: val_f1_m did not improve from 0.75200
# Epoch 12/80
# 100/100 [==============================] - 107s 1s/step - loss: 0.4142 - accuracy: 0.8098 - f1_m: 0.8091 - precision_m: 0.8140 - recall_m: 0.8125 - val_loss: 0.6139 - val_accuracy: 0.6989 - val_f1_m: 0.6395 - val_precision_m: 0.8236 - val_recall_m: 0.5313
#
# Epoch 00012: val_f1_m did not improve from 0.75200
# Epoch 13/80
# 100/100 [==============================] - 108s 1s/step - loss: 0.4120 - accuracy: 0.8147 - f1_m: 0.8121 - precision_m: 0.8219 - recall_m: 0.8103 - val_loss: 0.7693 - val_accuracy: 0.6540 - val_f1_m: 0.4949 - val_precision_m: 0.8210 - val_recall_m: 0.3587
#
# Epoch 00013: val_f1_m did not improve from 0.75200
# Epoch 14/80
# 100/100 [==============================] - 106s 1s/step - loss: 0.3820 - accuracy: 0.8270 - f1_m: 0.8261 - precision_m: 0.8307 - recall_m: 0.8286 - val_loss: 0.7059 - val_accuracy: 0.7102 - val_f1_m: 0.7157 - val_precision_m: 0.7251 - val_recall_m: 0.7144
#
# Epoch 00014: val_f1_m did not improve from 0.75200
# Epoch 15/80
# 100/100 [==============================] - 108s 1s/step - loss: 0.4092 - accuracy: 0.8125 - f1_m: 0.8038 - precision_m: 0.8190 - recall_m: 0.7988 - val_loss: 0.9525 - val_accuracy: 0.6427 - val_f1_m: 0.4733 - val_precision_m: 0.8217 - val_recall_m: 0.3390
#
# Epoch 00015: val_f1_m did not improve from 0.75200
# Epoch 16/80
# 100/100 [==============================] - 107s 1s/step - loss: 0.3760 - accuracy: 0.8293 - f1_m: 0.8276 - precision_m: 0.8366 - recall_m: 0.8287 - val_loss: 0.6964 - val_accuracy: 0.6790 - val_f1_m: 0.5654 - val_precision_m: 0.7802 - val_recall_m: 0.4491
#
# Epoch 00016: val_f1_m did not improve from 0.75200
# Epoch 17/80
# 100/100 [==============================] - 107s 1s/step - loss: 0.3458 - accuracy: 0.8442 - f1_m: 0.8442 - precision_m: 0.8505 - recall_m: 0.8444 - val_loss: 0.6445 - val_accuracy: 0.7002 - val_f1_m: 0.6032 - val_precision_m: 0.7916 - val_recall_m: 0.4919
#
# Epoch 00017: val_f1_m did not improve from 0.75200
# Epoch 18/80
# 100/100 [==============================] - 107s 1s/step - loss: 0.3331 - accuracy: 0.8558 - f1_m: 0.8512 - precision_m: 0.8667 - recall_m: 0.8452 - val_loss: 1.0674 - val_accuracy: 0.6134 - val_f1_m: 0.6690 - val_precision_m: 0.5522 - val_recall_m: 0.8591
#
# Epoch 00018: val_f1_m did not improve from 0.75200
# Epoch 19/80
# 100/100 [==============================] - 107s 1s/step - loss: 0.3527 - accuracy: 0.8489 - f1_m: 0.8472 - precision_m: 0.8530 - recall_m: 0.8498 - val_loss: 0.5508 - val_accuracy: 0.7439 - val_f1_m: 0.6802 - val_precision_m: 0.7853 - val_recall_m: 0.6046
#
# Epoch 00019: val_f1_m did not improve from 0.75200
# Epoch 20/80
# 100/100 [==============================] - 107s 1s/step - loss: 0.3153 - accuracy: 0.8651 - f1_m: 0.8640 - precision_m: 0.8770 - recall_m: 0.8585 - val_loss: 0.6653 - val_accuracy: 0.7196 - val_f1_m: 0.6312 - val_precision_m: 0.8148 - val_recall_m: 0.5199
#
# Epoch 00020: val_f1_m did not improve from 0.75200
# Epoch 00020: early stopping

# %%
import numpy as np
from keras.preprocessing import image

result = []

print("Predicting Cat Dataset:")
for img in os.listdir(f"{test_dir}/cats"):
#     os.system("cls")
    if img == "_DS_Store":
        continue

    test_image = image.load_img(f"{test_dir}/cats/{img}", target_size = (x.shape[0], x.shape[1]))
    test_image = image.img_to_array(test_image)
    test_image = np.expand_dims(test_image, axis = 0)/255
    if model.predict(test_image) < .5:
        result.append(1)
    else:
        result.append(0)
    

print("Accuracy for detcting only cat data: %.2f" %((sum(result)/len(result))*100))
print("Predicting Dog Dataset:")
for img in os.listdir(f"{test_dir}/dogs"):
    os.system("cls")
    if img == "_DS_Store":
        continue
#     print(img)
    test_image = image.load_img(f"{test_dir}/dogs/{img}", target_size = (x.shape[0], x.shape[1]))
    test_image = image.img_to_array(test_image)
    test_image = np.expand_dims(test_image, axis = 0)/255
    if model.predict(test_image) < .5:
        result.append(1)
    else:
        result.append(0)
        

        
print("Overall Accuracy: %.2f" %((sum(result)/len(result))*100))
# Out:
# Predicting Cat Dataset:
# Accuracy for detcting only cat data: 90.31
# Predicting Dog Dataset:
# Overall Accuracy: 67.28
