# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/customer-segmentation-tutorial-in-python/Mall_Customers.csv

# %% [markdown]
# This notebook contains KMeans clustering for mall customer segmentation. Please give me suggestions to improve this notebook :)

# %% [markdown]
# # Inspecting Dataset

# %%
df = pd.read_csv("/kaggle/input/customer-segmentation-tutorial-in-python/Mall_Customers.csv")

# %%
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %% [markdown]
# The data is already clean, we don't have to do further preprocessing

# %%
df.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %% [markdown]
# Let's inspect the distribution of each features

# %%
sns.countplot(df.Gender)
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# I think female might have higher spending score

# %%
print(df[df.Gender=="Female"]["Spending Score (1-100)"].mean())
print(df[df.Gender=="Male"]["Spending Score (1-100)"].mean())
# Out:
# 51.526785714285715
# 48.51136363636363

# %% [markdown]
# well yes, but not that much
#
# how about the distribution of other features?

# %%
sns.distplot(df.Age, kde = False)
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# <AxesSubplot:xlabel='Age'>

# %%
sns.distplot(df["Annual Income (k$)"], kde = False)
# Out:
# <AxesSubplot:xlabel='Annual Income (k$)'>

# %%
sns.distplot(df["Spending Score (1-100)"], kde = False)
# Out:
# <AxesSubplot:xlabel='Spending Score (1-100)'>

# %% [markdown]
# ummm.. can't tell much,
#
# let's plot spending score with annual income and age

# %%
sns.scatterplot(x = df["Annual Income (k$)"], y =df["Spending Score (1-100)"], hue=df.Gender)
# Out:
# <AxesSubplot:xlabel='Annual Income (k$)', ylabel='Spending Score (1-100)'>

# %%
sns.scatterplot(x = df.Age, y =df["Spending Score (1-100)"], hue=df.Gender)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Spending Score (1-100)'>

# %%
sns.pairplot(df)

# %% [markdown]
# It seems that we can do some clustering to divide the customer types, so we can focus on which customer to be the sales target.

# %% [markdown]
# # KMeans Clustering

# %% [markdown]
# I will divide clusters from two plot above, I will use elbow method to determine how many clusters I will use.

# %%
income_spending = df.iloc[:,3:5]
income_spending
# Out:
#      Annual Income (k$)  Spending Score (1-100)
# 0                    15                      39
# 1                    15                      81
# 2                    16                       6
# 3                    16                      77
# 4                    17                      40
# ..                  ...                     ...
# 195                 120                      79
# 196                 126                      28
# 197                 126                      74
# 198                 137                      18
# 199                 137                      83
#
# [200 rows x 2 columns]

# %%
from sklearn.cluster import KMeans

wcss = []
for i in range(1, 11):
    km = KMeans(n_clusters = i, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
    km.fit(income_spending)
    wcss.append(km.inertia_)
    
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method', fontsize = 20)
plt.xlabel('No. of Clusters')
plt.ylabel('wcss')
plt.show()

# %% [markdown]
# It seems that five is the best number

# %%
km = KMeans(n_clusters = 5, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
income_spending["cluster"] = km.fit_predict(income_spending)

# %%
income_spending
# Out:
#      Annual Income (k$)  Spending Score (1-100)  cluster
# 0                    15                      39        4
# 1                    15                      81        3
# 2                    16                       6        4
# 3                    16                      77        3
# 4                    17                      40        4
# ..                  ...                     ...      ...
# 195                 120                      79        2
# 196                 126                      28        0
# 197                 126                      74        2
# 198                 137                      18        0
# 199                 137                      83        2
#
# [200 rows x 3 columns]

# %%
cust_dict = {0:"target", 1:"usual", 2:"ideal", 3:"extravagant", 4:"possible"}

# %%
income_spending.y = income_spending["cluster"].map(cust_dict)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning:
#
# Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access

# %%
income_spending['y'] = y_means

# %%
sns.scatterplot(x = "Annual Income (k$)", y = "Spending Score (1-100)", hue = "y", data = income_spending, palette="tab10")
plt.scatter(km.cluster_centers_[:,0], km.cluster_centers_[:, 1], s = 50, c = 'blue' , label = 'centeroid')
plt.legend(bbox_to_anchor=(1, 1.05))

# %%
age_spending
# Out:
#      Age  Spending Score (1-100)         cluster
# 0     19                      39       potential
# 1     21                      81           ideal
# 2     20                       6  target (young)
# 3     23                      77           ideal
# 4     31                      40       potential
# ..   ...                     ...             ...
# 195   35                      79           ideal
# 196   45                      28  target (young)
# 197   32                      74           ideal
# 198   32                      18  target (young)
# 199   30                      83           ideal
#
# [200 rows x 3 columns]

# %%
age_spending = df[["Age", "Spending Score (1-100)"]]

# %%
wcss = []
for i in range(1, 11):
    km = KMeans(n_clusters = i, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
    km.fit(age_spending)
    wcss.append(km.inertia_)
    
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method', fontsize = 20)
plt.xlabel('No. of Clusters')
plt.ylabel('wcss')
plt.show()

# %%
km = KMeans(n_clusters = 4, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)

age_spending["cluster"] =  km.fit_predict(age_spending)
cust_dict = {0:"target (young)", 1:"ideal", 2:"potential", 3:"target(old)"}
age_spending["cluster"] = age_spending["cluster"].map(cust_dict)

age_spending
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      Age  Spending Score (1-100)         cluster
# 0     19                      39       potential
# 1     21                      81           ideal
# 2     20                       6  target (young)
# 3     23                      77           ideal
# 4     31                      40       potential
# ..   ...                     ...             ...
# 195   35                      79           ideal
# 196   45                      28  target (young)
# 197   32                      74           ideal
# 198   32                      18  target (young)
# 199   30                      83           ideal
#
# [200 rows x 3 columns]

# %%
sns.scatterplot(x="Age", y="Spending Score (1-100)", hue="cluster", data=age_spending, palette="tab10")
plt.scatter(km.cluster_centers_[:,0], km.cluster_centers_[:, 1], s = 50, c = 'blue' , label = 'centeroid')
plt.legend(bbox_to_anchor=(1, 1))

# %%
df3d = df[["Age", "Annual Income (k$)", "Spending Score (1-100)"]]

# %%
km = KMeans(n_clusters = 5, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
df3d["cluster"] = km.fit_predict(df3d)
cust_dict = {0:"ideal", 1:"possible", 2:"usual", 3:"extravagant", 4:"target"}
df3d.cluster = df3d.cluster.map(cust_dict)
df3d
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py:5494: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      Age  Annual Income (k$)  Spending Score (1-100)      cluster
# 0     19                  15                      39        ideal
# 1     21                  15                      81       target
# 2     20                  16                       6        ideal
# 3     23                  16                      77       target
# 4     31                  17                      40        ideal
# ..   ...                 ...                     ...          ...
# 195   35                 120                      79     possible
# 196   45                 126                      28  extravagant
# 197   32                 126                      74     possible
# 198   32                 137                      18  extravagant
# 199   30                 137                      83     possible
#
# [200 rows x 4 columns]

# %%
import plotly.graph_objs as go

# %%
import plotly.express as px

fig = px.scatter_3d(df3d, x="Annual Income (k$)", y="Spending Score (1-100)", z="Age",
                    color='cluster')
# px.scatter_3d(km.cluster_centers_[:,0], km.cluster_centers_[:, 1], s = 50, c = 'blue' , label = 'centeroid')

fig.show()
# Out:
# <div>                            <div id="c3310572-040e-485f-8693-2b4598a55c4c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c3310572-040e-485f-8693-2b4598a55c4c")) {                    Plotly.newPlot(                        "c3310572-040e-485f-8693-2b4598a55c4c",                        [{"hovertemplate": "cluster=ideal<br>Annual Income (k$)=%{x}<br>Spending Score (1-100)=%{y}<br>Age=%{z}<extra></extra>", "legendgroup": "ideal", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "ideal", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [15, 16, 17, 18, 19, 19, 20, 20, 21, 23, 24, 25, 28, 28, 29, 30, 33, 33, 34, 37, 38, 39, 39], "y": [39, 6, 40, 6, 3, 14, 15, 13, 35, 29, 35, 5, 14, 32, 31, 4, 4, 14, 17, 26, 35, 36, 28], "z": [19, 20, 31, 35, 64, 67, 58, 37, 35, 52, 35, 46, 54, 45, 40, 60, 53, 49, 42, 36, 65, 48, 49]}, {"hovertemplate": "cluster=target<br>Annual Income (k$)=%{x}<br>Spending Score (1-100)=%{y}<br>Age=%{z}<extra></extra>", "legendgroup": "target", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "markers", "name": "target", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [15, 16, 17, 18, 19, 19, 20, 20, 21, 23, 24, 25, 28, 28, 29, 30, 33, 33, 34, 37, 38, 39, 39], "y": [81, 77, 76, 94, 72, 99, 77, 79, 66, 98, 73, 73, 82, 61, 87, 73, 92, 81, 73, 75, 92, 61, 65], "z": [21, 23, 22, 23, 30, 35, 24, 22, 20, 35, 25, 31, 29, 35, 23, 21, 18, 21, 30, 20, 24, 31, 24]}, {"hovertemplate": "cluster=usual<br>Annual Income (k$)=%{x}<br>Spending Score (1-100)=%{y}<br>Age=%{z}<extra></extra>", "legendgroup": "usual", "marker": {"color": "#00cc96", "symbol": "circle"}, "mode": "markers", "name": "usual", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [40, 40, 40, 40, 42, 42, 43, 43, 43, 43, 44, 44, 46, 46, 46, 46, 47, 47, 48, 48, 48, 48, 48, 48, 49, 49, 50, 50, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 57, 57, 58, 58, 59, 59, 60, 60, 60, 60, 60, 60, 61, 61, 62, 62, 62, 62, 62, 62, 63, 63, 63, 63, 63, 63, 64, 64, 65, 65, 65, 65, 67, 67, 67, 67, 69, 71, 76], "y": [55, 47, 42, 42, 52, 60, 54, 60, 45, 41, 50, 46, 51, 46, 56, 55, 52, 59, 51, 59, 50, 48, 59, 47, 55, 42, 49, 56, 47, 54, 53, 48, 52, 42, 51, 55, 41, 44, 57, 46, 58, 55, 60, 46, 55, 41, 49, 40, 42, 52, 47, 50, 42, 49, 41, 48, 59, 55, 56, 42, 50, 46, 43, 48, 52, 54, 42, 46, 48, 50, 43, 59, 43, 57, 56, 40, 58, 35, 40], "z": [50, 27, 29, 31, 49, 33, 31, 59, 50, 47, 51, 69, 27, 53, 70, 19, 67, 54, 63, 18, 43, 68, 19, 32, 70, 47, 60, 60, 59, 26, 45, 40, 23, 49, 57, 38, 67, 46, 21, 48, 55, 22, 34, 50, 68, 18, 48, 40, 32, 24, 47, 27, 48, 20, 23, 49, 67, 26, 49, 21, 66, 54, 68, 66, 65, 19, 38, 19, 18, 19, 63, 49, 51, 50, 27, 38, 40, 43, 28]}, {"hovertemplate": "cluster=possible<br>Annual Income (k$)=%{x}<br>Spending Score (1-100)=%{y}<br>Age=%{z}<extra></extra>", "legendgroup": "possible", "marker": {"color": "#ab63fa", "symbol": "circle"}, "mode": "markers", "name": "possible", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [69, 70, 71, 71, 71, 72, 73, 73, 74, 75, 76, 77, 77, 78, 78, 78, 78, 78, 78, 79, 81, 85, 86, 87, 87, 87, 88, 88, 93, 97, 98, 99, 101, 103, 103, 113, 120, 126, 137], "y": [91, 77, 95, 75, 75, 71, 88, 73, 72, 93, 87, 97, 74, 90, 88, 76, 89, 78, 73, 83, 93, 75, 95, 63, 75, 92, 86, 69, 90, 86, 88, 97, 68, 85, 69, 91, 79, 74, 83], "z": [39, 31, 40, 38, 39, 31, 29, 32, 35, 32, 32, 28, 32, 34, 39, 38, 27, 30, 30, 29, 31, 36, 33, 32, 28, 36, 30, 27, 35, 32, 29, 30, 28, 36, 32, 38, 35, 32, 30]}, {"hovertemplate": "cluster=extravagant<br>Annual Income (k$)=%{x}<br>Spending Score (1-100)=%{y}<br>Age=%{z}<extra></extra>", "legendgroup": "extravagant", "marker": {"color": "#FFA15A", "symbol": "circle"}, "mode": "markers", "name": " ...

# %%
df3d.cluster
# Out:
# 0            ideal
# 1           target
# 2            ideal
# 3           target
# 4            ideal
#           ...
# 195       possible
# 196    extravagant
# 197       possible
# 198    extravagant
# 199       possible
# Name: cluster, Length: 200, dtype: object
